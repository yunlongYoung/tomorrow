# %%
from pandas import read_excel
from sys import path
path.append('..')
from model.models import db, Location
xlsx = 'H:/xfjy/tomorrow/data/region_code_list.xlsx'
df = read_excel(xlsx)
df = df.where(df.notnull(), None)
sql_3 = Location.insert_many(
    df.values,
    [Location.id, Location.province, Location.city, Location.county, Location.country, Location.village, Location.neighborhood],
)
db.connect(reuse_if_open=True)
# 执行插入
with db.transaction():
    sql_3.execute()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3159             try:
# -> 3160                 cursor.execute(sql, params or ())
#    3161             except Exception:
#
# UniqueViolation: 错误:  重复键违反唯一约束"location_pkey"
# DETAIL:  键值"(id)=(110000)" 已经存在
#
#
# During handling of the above exception, another exception occurred:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13720/2260424970.py in <module>
#      20 db.connect()
#      21 # 执行插入
# ---> 22 sql_3.execute()
#      23 db.close()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in inner(self, database, *args, **kwargs)
#    1909             raise InterfaceError('Query must be bound to a database in order '
#    1910                                  'to call "%s".' % method.__name__)
# -> 1911         return method(self, database, *args, **kwargs)
#    1912     return inner
#    1913
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in execute(self, database)
#    1980     @database_required
#    1981     def execute(self, database):
# -> 1982         return self._execute(database)
#    1983
#    1984     def _execute(self, database):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in _execute(self, database)
#    2759             self._returning = (self.table._primary_key,)
#    2760         try:
# -> 2761             return super(Insert, self)._execute(database)
#    2762         except self.DefaultValuesException:
#    2763             pass
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in _execute(self, database)
#    2475     def _execute(self, database):
#    2476         if self._returning:
# -> 2477             cursor = self.execute_returning(database)
#    2478         else:
#    2479             cursor = database.execute(self)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in execute_returning(self, database)
#    2482     def execute_returning(self, database):
#    2483         if self._cursor_wrapper is None:
# -> 2484             cursor = database.execute(self)
#    2485             self._cursor_wrapper = self._get_cursor_wrapper(cursor)
#    2486         return self._cursor_wrapper
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in execute(self, query, commit, **context_options)
#    3171         ctx = self.get_sql_context(**context_options)
#    3172         sql, params = ctx.sql(query).query()
# -> 3173         return self.execute_sql(sql, params, commit=commit)
#    3174
#    3175     def get_context_options(self):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3155                 commit = not sql[:6].lower().startswith('select')
#    3156
# -> 3157         with __exception_wrapper__:
#    3158             cursor = self.cursor(commit)
#    3159             try:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in __exit__(self, exc_type, exc_value, traceback)
#    2931             new_type = self.exceptions[exc_type.__name__]
#    2932             exc_args = exc_value.args
# -> 2933             reraise(new_type, new_type(exc_value, *exc_args), traceback)
#    2934
#    2935
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in reraise(tp, value, tb)
#     189     def reraise(tp, value, tb=None):
#     190         if value.__traceback__ is not tb:
# --> 191             raise value.with_traceback(tb)
#     192         raise value
#     193
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3158             cursor = self.cursor(commit)
#    3159             try:
# -> 3160                 cursor.execute(sql, params or ())
#    3161             except Exception:
#    3162                 if self.autorollback and not self.in_transaction():
#
# IntegrityError: 错误:  重复键违反唯一约束"location_pkey"
# DETAIL:  键值"(id)=(110000)" 已经存在
